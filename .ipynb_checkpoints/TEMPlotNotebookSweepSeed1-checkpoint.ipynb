# %%
import torch
import numpy as np
import test
import matplotlib.pyplot as plt
from matplotlib import cm
from time import time
import analyse
from importlib import reload
from itertools import permutations
import world
import glob
import plot
from scipy.sparse.csgraph import shortest_path
from copy import deepcopy

# %%
def trajectory_len(trajectory):
    return abs(trajectory[1] - trajectory[0]) * 2 + 6

# %%
def make_trajectory_dict():
    trajectories = permutations(np.arange(6), r=2)
    trajectory_dict = {}
    for traj_idx, traj in enumerate(trajectories):
        trajectory_dict[traj] = traj_idx
    return trajectory_dict

# %%
def locations_in_trajectory(trajectory, environment):
    
    adjacency = np.array(self.adjacency) 
    dists, pred = shortest_path(adjacency, directed=False, method='FW', return_predecessors=True)

    trajectory_locs = [environment.locations[state_id] for state_id in self.get_path(pred, curr_arm_end_state, new_arm_end_state)][1:]

# %%
def print_proper_time(seconds):
    # hours
    if seconds > 3600:
        output_str = '{0} hours'.format(seconds / 3600)
    # minutes
    elif seconds > 60:
        output_str = '{0} minutes'.format(seconds / 60)
    # seconds
    else:
        output_str = '{0} seconds'.format(seconds)
    return 'Finished running in ' + output_str

# %%
IDX = '16000'

# %%
# 2022-04-21; run0 uses purely sweeping policy
DATE = '2022-08-02'
RUN = '0'
PATH = '/cumulus/cristofer/TEM_data/{0}/run{1}/model/'.format(DATE, RUN)
SAVE_DIR = '/cumulus/cristofer/TEM_figs/{0}/run{1}/'.format(DATE, RUN)

# %%
params = torch.load('/cumulus/cristofer/TEM_data/' + DATE + '/run' + RUN + '/model/params_' + IDX + '.pt')

# Make list of all the environments that this model was trained on
env_list = list(glob.iglob('/cumulus/cristofer/TEM_data/' + DATE + '/run' + RUN + '/script/envs/*'))

# Set which environments will include shiny objects
shiny_envs = [False, False, False, False]
# Set the number of walks to execute in parallel (batch size)
n_walks = len(shiny_envs)
# Select environments from the environments included in training
environments = [world.World(graph, randomise_observations=params['randomise_observations'], shiny=(params['shiny'] if shiny_envs[env_i] else None), specify_behavior=params['specify_behavior'], behavior_type=params['behavior_type'], seed=0) for env_i, graph in enumerate(np.random.choice(env_list, n_walks))]

# %%
fwd, mod, envs = test.get_forward(date=DATE, run=RUN, env_to_plot=0, index=IDX, seed=0)

# %%
all_g_sweep, all_p_sweep = analyse.trajectories_rate_maps(fwd, mod, envs)

# %%
np.array(all_p_sweep[0][0][0])[:, 0]
# Out:
# array([-9.99000000e+02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -4.61686635e-03,  0.00000000e+00,  0.00000000e+00, -4.67283232e-03,
#        -4.67134779e-03, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02, -9.99000000e+02, -9.99000000e+02, -9.99000000e+02,
#        -9.99000000e+02])

# %%
fig, ax = plt.subplots()#figsize=(100, 100))

im = plt.imread(SAVE_DIR + 'index_{0}_seed_0_performance.png'.format(IDX))

ax.imshow(im)

# %%
fig, ax = plt.subplots(figsize=(100, 100))

im = plt.imread(SAVE_DIR + 'index_{0}_seed_0_Hippocampal_cells.png'.format(IDX))

ax.imshow(im)

# %%
FREQUENCY = 0
plot.plot_single_frequency_all_cells_all_trajectories(all_p_sweep[0], frequency=FREQUENCY, environment=environments[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-95ed1bc6dfbf> in <module>
#       1 FREQUENCY = 0
# ----> 2 plot.plot_single_frequency_all_cells_all_trajectories(all_p_sweep[0], frequency=FREQUENCY, environment=environments[0])
#
# ~/projects/torch_tem/plot.py in plot_single_frequency_all_cells_all_trajectories(p_env, frequency, environment, num_cols, verbose)
#     177
#     178     for cell_num in np.arange(p_env[frequency][0][0].shape[0]):
# --> 179         plot_single_cell_all_trajectories(p_env, frequency, cell_num, environment, num_cols, verbose)
#     180
#     181
#
# ~/projects/torch_tem/plot.py in plot_single_cell_all_trajectories(p_env, frequency, cell_num, environment, num_cols, verbose)
#     182 def plot_single_cell_all_trajectories(p_env, frequency, cell_num, environment, num_cols=13, verbose=False):
#     183
# --> 184     fig, axs = plt.subplots(6, 6, figsize=(10, 6), tight_layout=True)
#     185     traj_by_loc_by_cell = np.array(p_env[frequency])
#     186     # Find min and max but ignore -999 which signifies locations that were never visited
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1438     """
#    1439     fig = figure(**fig_kw)
# -> 1440     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1441                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1442                        gridspec_kw=gridspec_kw)
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     909             gridspec_kw = {}
#     910         gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 911         axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     912                           subplot_kw=subplot_kw)
#     913         return axs
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     305                 subplot_kw["sharex"] = shared_with[sharex]
#     306                 subplot_kw["sharey"] = shared_with[sharey]
# --> 307                 axarr[row, col] = figure.add_subplot(
#     308                     self[row, col], **subplot_kw)
#     309
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     782             projection_class, pkw = self._process_projection_requirements(
#     783                 *args, **kwargs)
# --> 784             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     785             key = (projection_class, pkw)
#     786         return self._add_axes_internal(ax, key)
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      34         """
#      35         # _axes_class is set in the subplot_class_factory
# ---> 36         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      37         # This will also update the axes position.
#      38         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     632
#     633         self._rasterization_zorder = None
# --> 634         self.cla()
#     635
#     636         # funcs used to format x and y - fall back on major formatters
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axes/_base.py in cla(self)
#    1243         self.containers = []
#    1244
# -> 1245         self.grid(False)  # Disable grid on init to use rcParameter
#    1246         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1247                   axis=mpl.rcParams['axes.grid.axis'])
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    3062         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3063         if axis in ['x', 'both']:
# -> 3064             self.xaxis.grid(b, which=which, **kwargs)
#    3065         if axis in ['y', 'both']:
#    3066             self.yaxis.grid(b, which=which, **kwargs)
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1431             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1432                                 if b is TOGGLE else b)
# -> 1433             self.set_tick_params(which='major', **gridkw)
#    1434         self.stale = True
#    1435
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     854             if which in ['major', 'both']:
#     855                 self._major_tick_kw.update(kwtrans)
# --> 856                 for tick in self.majorTicks:
#     857                     tick._apply_params(**kwtrans)
#     858             if which in ['minor', 'both']:
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     606                 instance.majorTicks = []
#     607                 tick = instance._get_tick(major=True)
# --> 608                 instance.majorTicks.append(tick)
#     609                 return instance.majorTicks
#     610             else:
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     605             if self._major:
#     606                 instance.majorTicks = []
# --> 607                 tick = instance._get_tick(major=True)
#     608                 instance.majorTicks.append(tick)
#     609                 return instance.majorTicks
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2057         else:
#    2058             tick_kw = self._minor_tick_kw
# -> 2059         return XTick(self.axes, 0, major=major, **tick_kw)
#    2060
#    2061     def set_label_position(self, position):
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     418
#     419     def __init__(self, *args, **kwargs):
# --> 420         super().__init__(*args, **kwargs)
#     421         # x in data coords, y in axes coords
#     422         self.tick1line.set(
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     180                            ("_get_text1", "label1"),
#     181                            ("_get_text2", "label2")]:
# --> 182             overridden_method = _api.deprecate_method_override(
#     183                 getattr(__class__, meth), self, since="3.3", message="Relying "
#     184                 f"on {meth} to initialize Tick.{attr} is deprecated since "
#
# KeyboardInterrupt:

# %%
FREQUENCY = 1
plot.plot_single_frequency_all_cells_all_trajectories(all_p_sweep[0], frequency=FREQUENCY, environment=environments[0])

# %%
FREQUENCY = 2
plot.plot_single_frequency_all_cells_all_trajectories(all_p_sweep[0], frequency=FREQUENCY, environment=environments[0])

# %%
FREQUENCY = 3
plot.plot_single_frequency_all_cells_all_trajectories(all_p_sweep[0], frequency=FREQUENCY, environment=environments[0])

# %%
FREQUENCY = 4
plot.plot_single_frequency_all_cells_all_trajectories(all_p_sweep[0], frequency=FREQUENCY, environment=environments[0])

# %%
IDX2 = '39000'

# %%
# 2022-04-21; run1 uses random arm policy
DATE = '2022-08-02'
RUN = '1'
PATH = '/cumulus/cristofer/TEM_data/{0}/run{1}/model/'.format(DATE, RUN)
SAVE_DIR = '/cumulus/cristofer/TEM_figs/{0}/run{1}/'.format(DATE, RUN)

# %%
params = torch.load('/cumulus/cristofer/TEM_data/' + DATE + '/run' + RUN + '/model/params_' + IDX2 + '.pt')

# Make list of all the environments that this model was trained on
env_list = list(glob.iglob('/cumulus/cristofer/TEM_data/' + DATE + '/run' + RUN + '/script/envs/*'))

# Set which environments will include shiny objects
shiny_envs = [False, False, False, False]
# Set the number of walks to execute in parallel (batch size)
n_walks = len(shiny_envs)
# Select environments from the environments included in training
environments = [world.World(graph, randomise_observations=params['randomise_observations'], shiny=(params['shiny'] if shiny_envs[env_i] else None), specify_behavior=params['specify_behavior'], behavior_type=params['behavior_type'], seed=0) for env_i, graph in enumerate(np.random.choice(env_list, n_walks))]

# %%
fwd, mod, envs = test.get_forward(date=DATE, run=RUN, env_to_plot=0, index=IDX2, seed=0)

# %%
all_g_random, all_p_random = analyse.trajectories_rate_maps(fwd, mod, envs)

# %%
np.array(all_p_random[0][0][0])[:, 0]

# %%
fig, ax = plt.subplots()#figsize=(100, 100))

im = plt.imread(SAVE_DIR + 'index_{0}_seed_0_performance.png'.format(IDX2))

ax.imshow(im)

# %%
fig, ax = plt.subplots(figsize=(100, 100))

im = plt.imread(SAVE_DIR + 'index_{0}_seed_0_Hippocampal_cells.png'.format(IDX2))

ax.imshow(im)

# %%
FREQUENCY = 0
plot.plot_single_frequency_all_cells_all_trajectories(all_p_random[0], frequency=FREQUENCY, environment=environments[0])

# %%
FREQUENCY = 1
plot.plot_single_frequency_all_cells_all_trajectories(all_p_random[0], frequency=FREQUENCY, environment=environments[0])

# %%
FREQUENCY = 2
plot.plot_single_frequency_all_cells_all_trajectories(all_p_random[0], frequency=FREQUENCY, environment=environments[0])

# %%
FREQUENCY = 3
plot.plot_single_frequency_all_cells_all_trajectories(all_p_random[0], frequency=FREQUENCY, environment=environments[0])

# %%
FREQUENCY = 4
plot.plot_single_frequency_all_cells_all_trajectories(all_p_random[0], frequency=FREQUENCY, environment=environments[0])

# %%
trajectories = list(permutations(np.arange(6), r=2))

# %%
trajectories

# %%
def get_path(pred, start, goal):
    path = [goal]
    k = goal
    while pred[start, k] != -9999:
        path.append(pred[start, k])
        k = pred[start, k]
    return path[::-1]

# %%
def get_trajectory_states(trajectory, environment):
    
    trajectory_dict = analyse.make_trajectory_dict()
    # Calculate graph properties for shortest path calculation between arms
    adjacency = np.array(environment.adjacency) 
    dists, pred = shortest_path(adjacency, directed=False, method='FW', return_predecessors=True)

    curr_arm_end_state = trajectory[0] * 5
    new_arm_end_state = trajectory[1] * 5
    # Using the adjacency matrix, create a trajectory using a shortest path traversal from end of curr_arm to end of new_arm
    #trajectory = self.get_path(pred, curr_arm_end_state, new_arm_end_state)[1:]
    #print(trajectory)
    
    return [environment.locations[state_id]['id'] for state_id in get_path(pred, curr_arm_end_state, new_arm_end_state)][1:]

# %%
state_seq_a = np.array(get_trajectory_states((1, 0), envs[0]))
state_seq_b = np.array(get_trajectory_states((1, 2), envs[0]))
unambiguous_locs = state_seq_a != state_seq_b
print(state_seq_a)
print(state_seq_b)
print(state_seq_a[unambiguous_locs])
print(state_seq_b[unambiguous_locs])

# %%
def linearize_trajectory(p_env, frequency, trajectory, cell_num, environment):

    trajectory_states = get_trajectory_states(trajectory, environment)
    trajectory_i = trajectory_dict[trajectory]
    
    linearized_rate = np.array(p_env[frequency][trajectory_i])[:, cell_num][trajectory_states]
    
    return linearized_rate

# %%
def linearize_neighbor_trajectories(p_env, frequency, cell_num, environment):
    
    all_trajectories = analyse.make_trajectory_dict()
    neighbor_trajectories = [trajectory for trajectory in all_trajectories if abs(trajectory[0] - trajectory[1]) == 1]
    
    linearized_dict = {}
    
    for trajectory in neighbor_trajectories:
        linearized_dict[trajectory] = linearize_trajectory(p_env, frequency,  trajectory, cell_num, environment)
    
    return linearized_dict

# %%
ld_sweep = linearize_neighbor_trajectories(all_p_sweep[0], 4, 36, environments[0])

# %%
all_trajectories = analyse.make_trajectory_dict()
neighbor_trajectories = [trajectory for trajectory in all_trajectories if abs(trajectory[0] - trajectory[1]) == 1]

# %%
all_p_sweep_nonnegative = analyse.make_all_p_nonnegative(all_p_sweep[0])
all_p_random_nonnegative = analyse.make_all_p_nonnegative(all_p_random[0])

# %%
plot.plot_single_cell_all_trajectories(all_p_random[0], frequency=0, cell_num=44, environment=environments[0])
